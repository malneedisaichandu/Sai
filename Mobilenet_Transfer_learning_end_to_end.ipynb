# %% [markdown]
# <a href="https://colab.research.google.com/github/malneedisaichandu/Sai/blob/dev/Mobilenet_Transfer_learning_end_to_end.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## importing MobileNet using Keras model

# %%
import keras

# %% [markdown]
# ## Transfer learning
#
# - It is a pre trained model
#
# - already trained model we are using for our use cases
#
# - This type of learning is called tranfer learning

# %% [markdown]
# Google has taken 1.3M images which consist 1000 classes
#
# Our MNIST data set 60k 10 classes
#
# Every image they will draw the bounding box
# it will 4 coordinates
#
# top left corner:(x,y)
# Bottom right corner:(x+w,y+h)
#
# They created a dataset
# 1. Image
# 2. Cordinates
# 3. Class
#
# This data pass to CNV then they train the model
# once they got the good accuracy the save the model
# 1. Model configuration
#         how many layers
#         what are the parameters
# 2. Model weights
# ==========================================

# %% [markdown]
# ### MobileNet
#
# - You can read using keras
#
# - You can read using tensorflow

# %% [markdown]
# **Examples**
#
# https://keras.io/api/applications/#usage-examples-for-image-classification-models

# %% [markdown]
# **Using Keras**

# %%
import keras
mobile = keras.applications.mobilenet.MobileNet()

# %%
dir(mobile)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_trackable_child',
#  '_add_variable_with_custom_getter',
#  '_adjust_input_rank',
#  '_aggregate_additional_loss',
#  '_allow_non_tensor_positional_args',
#  '_api_export_path',
#  '_api_export_symbol_id',
#  '_assert_compile_called',
#  '_assert_input_compatibility',
#  '_assign_variable_values',
#  '_auto_config',
#  '_build_by_run_for_kwargs',
#  '_build_by_run_for_single_pos_arg',
#  '_build_shapes_dict',
#  '_call_has_mask_arg',
#  '_call_has_training_arg',
#  '_call_signature',
#  '_called',
# ...

# %%
mobile.name
# mobile net trained with some images
# 224x224
# Out:
# 'mobilenet_1.00_224'

# %%
mobile.input_shape
# Out:
# (None, 224, 224, 3)

# %%
mobile.summary()
# Out:
# Model: "mobilenet_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 112, 112, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_bn (BatchNormalization)   │ (None, 112, 112, 32)   │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_relu (ReLU)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1 (DepthwiseConv2D)     │ (None, 112, 112, 32)   │           288 │
# ...

# %%
mobile.get_config()
# Out:
# {'name': 'mobilenet_1.00_224',
#  'trainable': True,
#  'layers': [{'module': 'keras.layers',
#    'class_name': 'InputLayer',
#    'config': {'batch_shape': (None, 224, 224, 3),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_layer_6'},
#    'registered_name': None,
#    'name': 'input_layer_6',
#    'inbound_nodes': []},
#   {'module': 'keras.layers',
#    'class_name': 'Conv2D',
#    'config': {'name': 'conv1',
#     'trainable': True,
#     'dtype': {'module': 'keras',
#      'class_name': 'DTypePolicy',
#      'config': {'name': 'float32'},
#      'registered_name': None},
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (2, 2),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'module': 'keras.initializers',
#      'class_name': 'GlorotUniform',
#      'config': {'seed': None},
# ...

# %%
mobile.get_config().keys()
# Out:
# dict_keys(['name', 'trainable', 'layers', 'input_layers', 'output_layers'])

# %%
mobile.get_config()['name']
# Out:
# 'mobilenet_1.00_224'

# %%
mobile.get_config()['trainable']
# Out:
# True

# %%
len(mobile.get_config()['layers'])
# Out:
# 91

# %%
mobile.get_config()['layers'][0]
# Out:
# {'module': 'keras.layers',
#  'class_name': 'InputLayer',
#  'config': {'batch_shape': (None, 224, 224, 3),
#   'dtype': 'float32',
#   'sparse': False,
#   'name': 'input_layer_12'},
#  'registered_name': None,
#  'name': 'input_layer_12',
#  'inbound_nodes': []}

# %%
mobile.get_config()['layers'][2]
# Out:
# {'module': 'keras.layers',
#  'class_name': 'BatchNormalization',
#  'config': {'name': 'conv1_bn',
#   'trainable': True,
#   'dtype': {'module': 'keras',
#    'class_name': 'DTypePolicy',
#    'config': {'name': 'float32'},
#    'registered_name': None},
#   'axis': -1,
#   'momentum': 0.99,
#   'epsilon': 0.001,
#   'center': True,
#   'scale': True,
#   'beta_initializer': {'module': 'keras.initializers',
#    'class_name': 'Zeros',
#    'config': {},
#    'registered_name': None},
#   'gamma_initializer': {'module': 'keras.initializers',
#    'class_name': 'Ones',
#    'config': {},
#    'registered_name': None},
#   'moving_mean_initializer': {'module': 'keras.initializers',
#    'class_name': 'Zeros',
#    'config': {},
#    'registered_name': None},
#   'moving_variance_initializer': {'module': 'keras.initializers',
#    'class_name': 'Ones',
#    'config': {},
#    'registered_name': None},
#   'beta_regularizer': None,
#   'gamma_regularizer': None,
# ...

# %%
mobile.get_weights()
# Out:
# [array([[[[ 8.87084053e-14,  3.11129272e-01,  1.19772255e-02,
#             1.65614850e-13,  1.67507152e-14,  2.31184348e-01,
#            -2.32737631e-01, -2.96911478e-01, -4.32953903e-15,
#             8.21083635e-02,  3.79058927e-01,  9.35078702e-14,
#             1.45881534e-01,  1.58076912e-01, -1.66753982e-03,
#             4.56319394e-05, -5.14434686e-13, -1.85627863e-01,
#             4.04302508e-01, -2.56781399e-01,  1.27436947e-13,
#             8.86099631e-15, -6.08684048e-02,  2.80227751e-01,
#             1.13050954e-03,  2.00989982e-03,  3.01095426e-01,
#            -1.71066225e-01, -5.65458477e-01,  2.62688458e-01,
#            -4.01542217e-01, -2.50179484e-03],
#           [ 1.05321493e-13, -3.48603338e-01,  3.99522372e-02,
#             1.44252747e-13,  5.91760866e-14,  1.67545795e-01,
#            -1.13974318e-01,  9.64645147e-02,  8.52340540e-15,
#            -1.87848985e-01,  3.75256538e-01,  1.19941383e-13,
# ...

# %%
mobile.get_weights()[5].shape
# 32 *3*3*3= 288*3=864
# Out:
# (3, 3, 32, 1)

# %%
len(mobile.get_weights())
# Out:
# 137

# %%
mobile.input_shape
# we need to pass the test image with this shape only
# Out:
# (None, 224, 224, 3)

# %%
mobile.inputs
# Out:
# [<KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor_871>]

# %%
mobile.name
# Out:
# 'mobilenet_1.00_224'

# %%
mobile.input_spec
# Out:
# [InputSpec(shape=(None, 224, 224, 3), ndim=4)]

# %%
layers=['input_3', 'conv1', 'conv1_bn', 'conv1_relu', 'conv_dw_1', 'conv_dw_1_bn', 'conv_dw_1_relu', 'conv_pw_1', 'conv_pw_1_bn', 'conv_pw_1_relu', 'conv_pad_2', 'conv_dw_2', 'conv_dw_2_bn', 'conv_dw_2_relu', 'conv_pw_2', 'conv_pw_2_bn', 'conv_pw_2_relu', 'conv_dw_3', 'conv_dw_3_bn', 'conv_dw_3_relu', 'conv_pw_3', 'conv_pw_3_bn', 'conv_pw_3_relu', 'conv_pad_4', 'conv_dw_4', 'conv_dw_4_bn', 'conv_dw_4_relu', 'conv_pw_4', 'conv_pw_4_bn', 'conv_pw_4_relu', 'conv_dw_5', 'conv_dw_5_bn', 'conv_dw_5_relu', 'conv_pw_5', 'conv_pw_5_bn', 'conv_pw_5_relu', 'conv_pad_6', 'conv_dw_6', 'conv_dw_6_bn', 'conv_dw_6_relu', 'conv_pw_6', 'conv_pw_6_bn', 'conv_pw_6_relu', 'conv_dw_7', 'conv_dw_7_bn', 'conv_dw_7_relu', 'conv_pw_7', 'conv_pw_7_bn', 'conv_pw_7_relu', 'conv_dw_8', 'conv_dw_8_bn', 'conv_dw_8_relu', 'conv_pw_8', 'conv_pw_8_bn', 'conv_pw_8_relu', 'conv_dw_9', 'conv_dw_9_bn', 'conv_dw_9_relu', 'conv_pw_9', 'conv_pw_9_bn', 'conv_pw_9_relu', 'conv_dw_10', 'conv_dw_10_bn', 'conv_dw_10_relu', 'conv_pw_10', 'conv_pw_10_bn', 'conv_pw_10_relu', 'conv_dw_11', 'conv_dw_11_bn', 'conv_dw_11_relu', 'conv_pw_11', 'conv_pw_11_bn', 'conv_pw_11_relu', 'conv_pad_12', 'conv_dw_12', 'conv_dw_12_bn', 'conv_dw_12_relu', 'conv_pw_12', 'conv_pw_12_bn', 'conv_pw_12_relu', 'conv_dw_13', 'conv_dw_13_bn', 'conv_dw_13_relu', 'conv_pw_13', 'conv_pw_13_bn', 'conv_pw_13_relu', 'global_average_pooling2d_2', 'dropout', 'conv_preds', 'reshape_2', 'predictions']

# %%
len(layers)
# Out:
# 91

# %% [markdown]
# **Using Tensorflow**

# %% [markdown]
# **Getting the Layer names**

# %%
import tensorflow as tf
dir(tf.keras.applications)
# Out:
# ['ConvNeXtBase',
#  'ConvNeXtLarge',
#  'ConvNeXtSmall',
#  'ConvNeXtTiny',
#  'ConvNeXtXLarge',
#  'DenseNet121',
#  'DenseNet169',
#  'DenseNet201',
#  'EfficientNetB0',
#  'EfficientNetB1',
#  'EfficientNetB2',
#  'EfficientNetB3',
#  'EfficientNetB4',
#  'EfficientNetB5',
#  'EfficientNetB6',
#  'EfficientNetB7',
#  'EfficientNetV2B0',
#  'EfficientNetV2B1',
#  'EfficientNetV2B2',
#  'EfficientNetV2B3',
#  'EfficientNetV2L',
#  'EfficientNetV2M',
#  'EfficientNetV2S',
#  'InceptionResNetV2',
#  'InceptionV3',
#  'MobileNet',
#  'MobileNetV2',
#  'MobileNetV3Large',
#  'MobileNetV3Small',
#  'NASNetLarge',
#  'NASNetMobile',
#  'ResNet101',
#  'ResNet101V2',
#  'ResNet152',
#  'ResNet152V2',
#  'ResNet50',
#  'ResNet50V2',
#  'VGG16',
#  'VGG19',
#  'Xception',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'convnext',
#  'densenet',
#  'efficientnet',
#  'efficientnet_v2',
# ...

# %% [markdown]
# **MobileNetV2**

# %%
mobile.layers
# Out:
# [<InputLayer name=input_layer_6, built=True>,
#  <Conv2D name=conv1, built=True>,
#  <BatchNormalization name=conv1_bn, built=True>,
#  <ReLU name=conv1_relu, built=True>,
#  <DepthwiseConv2D name=conv_dw_1, built=True>,
#  <BatchNormalization name=conv_dw_1_bn, built=True>,
#  <ReLU name=conv_dw_1_relu, built=True>,
#  <Conv2D name=conv_pw_1, built=True>,
#  <BatchNormalization name=conv_pw_1_bn, built=True>,
#  <ReLU name=conv_pw_1_relu, built=True>,
#  <ZeroPadding2D name=conv_pad_2, built=True>,
#  <DepthwiseConv2D name=conv_dw_2, built=True>,
#  <BatchNormalization name=conv_dw_2_bn, built=True>,
#  <ReLU name=conv_dw_2_relu, built=True>,
#  <Conv2D name=conv_pw_2, built=True>,
#  <BatchNormalization name=conv_pw_2_bn, built=True>,
#  <ReLU name=conv_pw_2_relu, built=True>,
#  <DepthwiseConv2D name=conv_dw_3, built=True>,
#  <BatchNormalization name=conv_dw_3_bn, built=True>,
#  <ReLU name=conv_dw_3_relu, built=True>,
#  <Conv2D name=conv_pw_3, built=True>,
# ...

# %%
import tensorflow as tf
# Load the MobileNetV2 model
model = tf.keras.applications.MobileNetV2()
dir(model)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_trackable_child',
#  '_add_variable_with_custom_getter',
#  '_adjust_input_rank',
#  '_aggregate_additional_loss',
#  '_allow_non_tensor_positional_args',
#  '_api_export_path',
#  '_api_export_symbol_id',
#  '_assert_compile_called',
#  '_assert_input_compatibility',
#  '_assign_variable_values',
#  '_auto_config',
#  '_build_by_run_for_kwargs',
#  '_build_by_run_for_single_pos_arg',
#  '_build_shapes_dict',
#  '_call_has_mask_arg',
#  '_call_has_training_arg',
#  '_call_signature',
#  '_called',
# ...

# %%
model
# Out:
# <Functional name=mobilenetv2_1.00_224, built=True>

# %%
import tensorflow as tf

# Load the MobileNetV2 model
model = tf.keras.applications.MobileNetV2()

# Get the names of all layers in the model
layer_names = [layer.name for layer in model.layers]

# Print the layer names
print(layer_names)
print(len(layer_names))

# it is version2  : 156   for V1: 91
# Out:
# ['input_layer_8', 'Conv1', 'bn_Conv1', 'Conv1_relu', 'expanded_conv_depthwise', 'expanded_conv_depthwise_BN', 'expanded_conv_depthwise_relu', 'expanded_conv_project', 'expanded_conv_project_BN', 'block_1_expand', 'block_1_expand_BN', 'block_1_expand_relu', 'block_1_pad', 'block_1_depthwise', 'block_1_depthwise_BN', 'block_1_depthwise_relu', 'block_1_project', 'block_1_project_BN', 'block_2_expand', 'block_2_expand_BN', 'block_2_expand_relu', 'block_2_depthwise', 'block_2_depthwise_BN', 'block_2_depthwise_relu', 'block_2_project', 'block_2_project_BN', 'block_2_add', 'block_3_expand', 'block_3_expand_BN', 'block_3_expand_relu', 'block_3_pad', 'block_3_depthwise', 'block_3_depthwise_BN', 'block_3_depthwise_relu', 'block_3_project', 'block_3_project_BN', 'block_4_expand', 'block_4_expand_BN', 'block_4_expand_relu', 'block_4_depthwise', 'block_4_depthwise_BN', 'block_4_depthwise_relu', 'block_4_project', 'block_4_project_BN', 'block_4_add', 'block_5_expand', 'block_5_expand_BN', 'block_5
# ...

# %%
len(layer_names)
# Out:
# 156

# %%
model.name
# Out:
# 'mobilenetv2_1.00_224'

# %% [markdown]
# **Getting the number of parameters**

# %%
import tensorflow as tf

# Load the MobileNetV2 model
model = tf.keras.applications.MobileNetV2()

# Count the number of parameters
num_params = sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

# Print the number of parameters
print("Number of parameters:", num_params)
# Out:
# Number of parameters: 3504872

# %% [markdown]
# **Getting the number of classes**

# %%
model.output_shape
# Out:
# (None, 1000)

# %%
import tensorflow as tf

# Load the MobileNetV2 model
model = tf.keras.applications.MobileNetV2()

# Get the number of classes
num_classes = model.output_shape[-1]

# Print the number of classes
print("Number of classes:", num_classes)
# Out:
# Number of classes: 1000

# %%
num_classes
# Out:
# 1000

# %%
import tensorflow as tf

# Load the MobileNetV2 model
model = tf.keras.applications.MobileNetV2()

# Load ImageNet class names
class_names_path = tf.keras.utils.get_file('ImageNetLabels.txt',
                        'https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
with open(class_names_path, 'r') as f:
    class_names = f.read().splitlines()

# Print the class names
print("Class names:", class_names)
# Out:
# Class names: ['background', 'tench', 'goldfish', 'great white shark', 'tiger shark', 'hammerhead', 'electric ray', 'stingray', 'cock', 'hen', 'ostrich', 'brambling', 'goldfinch', 'house finch', 'junco', 'indigo bunting', 'robin', 'bulbul', 'jay', 'magpie', 'chickadee', 'water ouzel', 'kite', 'bald eagle', 'vulture', 'great grey owl', 'European fire salamander', 'common newt', 'eft', 'spotted salamander', 'axolotl', 'bullfrog', 'tree frog', 'tailed frog', 'loggerhead', 'leatherback turtle', 'mud turtle', 'terrapin', 'box turtle', 'banded gecko', 'common iguana', 'American chameleon', 'whiptail', 'agama', 'frilled lizard', 'alligator lizard', 'Gila monster', 'green lizard', 'African chameleon', 'Komodo dragon', 'African crocodile', 'American alligator', 'triceratops', 'thunder snake', 'ringneck snake', 'hognose snake', 'green snake', 'king snake', 'garter snake', 'water snake', 'vine snake', 'night snake', 'boa constrictor', 'rock python', 'Indian cobra', 'green mamba', 'sea snake', 'h
# ...

# %%
len(class_names)
# Out:
# 1001

# %% [markdown]
# # Plot model
#
# - It is not available for all Models because of size

# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model

# Load the MobileNetV2 model
model = tf.keras.applications.MobileNetV2()

# Plot the model architecture
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# - How to read the model
#
# - Apply directory
#
# - What is the model name
#
# - What is the input shape
#
# - How many parameters
#
# - Dispaly the weights
#
# - How many layers are there
#
# - How many classes are there
#
# - What are the classes names
#
# - What is the config file
#
# - Draw the model

# %%
# /content/giraffe.jpg

# %%
from IPython.display import Image
img_2=Image(filename='/content/pexels-summerstock-333083.jpg')

# %% [markdown]
# we can load the image using
#
# 1.Keras.preprocessing
#
# 2.Pillow
#
# 3.OpenCV
#
# 4.Matplotlib
#
# 5.IPythonDisplay

# %% [markdown]
# - MobileNet input image shape= 224,224
#
# - we need to reshape the image
#
# - that we can do using numpy or using Keras

# %% [markdown]
# ## Read the Image using Keras

# %%
import keras
dir(keras.preprocessing)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'image',
#  'image_dataset_from_directory',
#  'sequence',
#  'text_dataset_from_directory',
#  'timeseries_dataset_from_array']

# %%
from keras.preprocessing import image
img = image.load_img('/content/pexels-summerstock-333083.jpg')
print(img.size) # (w,h)
print(img.width,img.height)
# Out:
# (3000, 2000)
# 3000 2000

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=773x512>

# %%
model.name,model.input_shape
# Out:
# ('mobilenetv2_1.00_224', (None, 224, 224, 3))

# %%
#from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
import numpy as np
# Mobile net input shape is (224,224)
img = image.load_img('/content/pexels-summerstock-333083.jpg',
                     target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img.size
# Out:
# (224, 224)

# %% [markdown]
# image will give the values by applying
#
# **image.img_to_array**
#
# it is very important
#
# - Q1) How we are reading the image
#
# - Q2) How we are getting image values

# %%
image  # picture has numbers
# if we want to see the number we need to convert into
# array
# method name : img_to_array
# class : image
# Out:
# <module 'keras.api.preprocessing.image' from '/usr/local/lib/python3.11/dist-packages/keras/api/preprocessing/image/__init__.py'>

# %%
from keras.preprocessing import image
img_array = image.img_to_array(img)
img_array.shape
# Out:
# (224, 224, 3)

# %%
# from keras.preprocessing import image
# import numpy as np
# # Mobile net input shape is (224,224)
# img = image.load_img('/content/eagle.jpg',color_mode='gray_scale'
#                      target_size=(224, 224))
# img

# %% [markdown]
# The Mobile net input shape is
#
# (None,224,224,3)
#
# It is 4 dimensions data
#
# So we need to convert 3D to 4D

# %%
import numpy as np
img_array_expanded_dims = np.expand_dims(img_array, axis=0)
img_array_expanded_dims.shape
# Out:
# (1, 224, 224, 3)

# %%
# import numpy as np
# img_array_expanded_dims_1 = np.expand_dims(img_array, axis=1)
# img_array_expanded_dims_1.shape

# %% [markdown]
# Step-1: Read the image
#
# Step-2: Change the shape to 224,224
#
# Step-3: It is by default color image so the shape is (224,224,3)
#
# Step-4: We required 4D data , so we converted to (1,224,224,3)

# %%
img_array_expanded_dims
# Out:
# array([[[[129., 136., 129.],
#          [133., 142., 137.],
#          [136., 147., 143.],
#          ...,
#          [ 59.,  63.,  40.],
#          [ 76.,  77.,  46.],
#          [ 83.,  73.,  38.]],
#
#         [[134., 141., 134.],
#          [134., 143., 138.],
#          [136., 147., 143.],
#          ...,
#          [ 65.,  69.,  46.],
#          [ 84.,  80.,  51.],
#          [100.,  85.,  52.]],
#
#         [[130., 132., 127.],
#          [129., 138., 133.],
#          [144., 154., 153.],
#          ...,
#          [ 66.,  69.,  48.],
#          [ 75.,  68.,  42.],
#          [102.,  83.,  53.]],
#
#         ...,
#
#         [[182., 163., 130.],
#          [208., 190., 152.],
#          [179., 157., 110.],
#          ...,
#          [185., 166., 124.],
#          [188., 173., 132.],
#          [158., 130.,  90.]],
#
#         [[173., 156., 113.],
#          [193., 170., 126.],
#          [181., 163., 123.],
#          ...,
#          [198., 178., 141.],
# ...

# %%
import keras
preprocess_img=keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)
preprocess_img.shape
# Out:
# (1, 224, 224, 3)

# %%
preprocess_img
# Out:
# array([[[[ 0.01176476,  0.06666672,  0.01176476],
#          [ 0.04313731,  0.11372554,  0.07450986],
#          [ 0.06666672,  0.15294123,  0.12156868],
#          ...,
#          [-0.5372549 , -0.5058824 , -0.6862745 ],
#          [-0.40392154, -0.3960784 , -0.6392157 ],
#          [-0.3490196 , -0.42745095, -0.7019608 ]],
#
#         [[ 0.05098045,  0.10588241,  0.05098045],
#          [ 0.05098045,  0.12156868,  0.082353  ],
#          [ 0.06666672,  0.15294123,  0.12156868],
#          ...,
#          [-0.49019605, -0.4588235 , -0.6392157 ],
#          [-0.34117645, -0.372549  , -0.6       ],
#          [-0.21568626, -0.3333333 , -0.5921569 ]],
#
#         [[ 0.0196079 ,  0.03529418, -0.00392157],
#          [ 0.01176476,  0.082353  ,  0.04313731],
#          [ 0.12941182,  0.20784318,  0.20000005],
#          ...,
#          [-0.4823529 , -0.4588235 , -0.62352943],
#          [-0.41176468, -0.46666664, -0.67058825],
#          [-0.19999999, -0.3490196 , -0.58431375]],
#
# ...

# %% [markdown]
# - Mobilenet Expects values [-1,1] Normalized

# %% [markdown]
# **Predictions**
#
# - when you do predictions , we will get 1000 probabilities
#
# - Because MobileNet model predict 1000 classes

# %%
model  # MobilenetV2
# Out:
# <Functional name=mobilenetv2_1.00_224, built=True>

# %%
predictions_v2=model.predict(preprocess_img)
predictions_v2.shape

# 1000 probabilties
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# (1, 1000)

# %%
np.argmax(predictions_v2)
# Out:
# np.int64(235)

# %%
class_names[np.argmax(predictions_v2)]
# Out:
# 'Rottweiler'

# %%
class_names[np.argmax(predictions_v2)+1]
# Out:
# 'German shepherd'

# %%
import keras
mobile = keras.applications.mobilenet.MobileNet() # V1 model
predictions_v1 = mobile.predict(preprocess_img)
predictions_v1.shape
print(np.argmax(predictions_v1))
print(num_classes)
print(class_names[np.argmax(predictions_v1)+1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 783ms/step
# 235
# 1000
# German shepherd

# %%
mobile.name
# Out:
# 'mobilenet_1.00_224'

# %% [markdown]
# **Decode Predictions**
#
# - Pass the classes probability arrat into the keras
#
# - It will give top 5 predictions

# %%
from keras.applications import imagenet_utils
results = imagenet_utils.decode_predictions(predictions_v1)
results
# predictions_v1 is from MobielNet version1
# we are reading from keras package
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n02106662', 'German_shepherd', np.float32(0.99846554)),
#   ('n02105162', 'malinois', np.float32(0.0008401979)),
#   ('n02111129', 'Leonberg', np.float32(0.00016926645)),
#   ('n02094258', 'Norwich_terrier', np.float32(0.00015827808)),
#   ('n02088466', 'bloodhound', np.float32(7.172615e-05))]]

# %%
from keras.applications import imagenet_utils
results = imagenet_utils.decode_predictions(predictions_v2)
results
# predictions_v1 is from MobielNet version1
# we are reading from tensforflow package
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n01614925', 'bald_eagle', np.float32(0.15219185)),
#   ('n01608432', 'kite', np.float32(0.117207766)),
#   ('n02025239', 'ruddy_turnstone', np.float32(0.10976163)),
#   ('n02013706', 'limpkin', np.float32(0.0753465)),
#   ('n01616318', 'vulture', np.float32(0.03616568))]]

# %%
vgg16
inception_v3
resnet50
